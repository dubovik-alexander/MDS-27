# %% [markdown]
# # Домашнее задание "Функции нескольких переменных".

# %% [markdown]
# ## Уровень 0:

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Посчитайте частные производные функций:
#
# 1) $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$
#
# 2) $f(x,y)=x^2y - sin(xy) + cos(x^2) + 6y$

# %% [markdown]
# ___

# %%
import sympy as sym

# %%
x = sym.Symbol('x')
y = sym.Symbol('y')

# %% [markdown]
# #### <span style="color:blue"> 1) $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$</span>

# %%
fxy1 = 2*(x**2)*(y**3) + 1/x + (y**2)*x + 7

# %% [markdown]
# #### Находим частные производные:

# %%
sym.diff(fxy1, x) # дифиринцируем по х
# Out:
# 4*x*y**3 + y**2 - 1/x**2

# %%
sym.diff(fxy1, y) # дифиринцируем по y
# Out:
# 6*x**2*y**2 + 2*x*y

# %% [markdown]
# #### Найдем смешанные частные производные (не по заданию, а для понимания как это работает):

# %%
sym.diff(sym.diff(fxy1, x), y) # дифиринцируем сначала по х, потом по y
# Out:
# 12*x*y**2 + 2*y

# %% [markdown]
# ___

# %% [markdown]
# #### <span style="color:blue"> 2) $f(x,y)=x^2y - sin(xy) + cos(x^2) + 6y$ </span>

# %%
fxy2 = (𝑥**2)*𝑦 - sym.𝑠𝑖𝑛(𝑥*𝑦) + sym.𝑐𝑜𝑠(𝑥**2) + 6*𝑦

# %% [markdown]
# #### Находим частные производные:

# %%
sym.diff(fxy2, x) # дифиринцируем по х
# Out:
# 2*x*y - 2*x*sin(x**2) - y*cos(x*y)

# %%
sym.diff(fxy2, y) # дифиринцируем по y
# Out:
# x**2 - x*cos(x*y) + 6

# %% [markdown]
# #### Найдем смешанные частные производные (не по заданию, а для понимания как это работает):

# %%
sym.diff(sym.diff(fxy2, x), y) # дифиринцируем сначала по х, потом по y
# Out:
# x*y*sin(x*y) + 2*x - cos(x*y)

# %% [markdown]
# ___

# %% [markdown]
# ## Уровень 1:

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Вычислите градиент функции:
#
# $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$
#
# в точке $(1,2)$

# %%
i = sym.Symbol('i')
j = sym.Symbol('j')

# %%
fxy3 = 2*(𝑥**2)*(𝑦**3) + 1/𝑥 + (𝑦**2)*𝑥 + 7

# %%
# Находим частные производные:

# %%
sym.diff(fxy3, x) # дифиринцируем по х
# Out:
# 4*x*y**3 + y**2 - 1/x**2

# %%
sym.diff(fxy3, y) # дифиринцируем по y
# Out:
# 6*x**2*y**2 + 2*x*y

# %%
# Тогда величина градиента равна:
    
grad_fxy3 = sym.diff(fxy3, x) * i + sym.diff(fxy3, y) * j
grad_fxy3
# Out:
# i*(4*x*y**3 + y**2 - 1/x**2) + j*(6*x**2*y**2 + 2*x*y)

# %%
grad_fxy3.evalf(subs = {'x':1, 'y':2})
# Out:
# 35.0*i + 28.0*j

# %% [markdown]
# ___

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Постройте трехмерный график функции
#
# $f(x)=x_2^2-x_1^2 x_2 + 2 x_1 x_2$

# %%
### Для упрощения х1 = х, х2 = y

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt

# %%
# уравнение поверхности
f = lambda x, y: y**2 - (x**2)*y + 2*x*y

# %%
fig = plt.figure(figsize = (10, 10))
ax = fig.add_subplot(1, 1, 1, projection = '3d')

# размечаем границы осей для аргументов
xval = np.linspace(-4, 6, 100)
yval = np.linspace(-5, 5, 100)


x, y = np.meshgrid(xval, yval)
# приравниваем z к функции от x и y 
z = f(x, y)

# График поверхности
surf = ax.plot_surface(x, y, z, rstride = 5, cstride = 5, cmap = cm.plasma)

# Цветовая легенда
fig.colorbar(surf, shrink=0.5, aspect=5)
